# %%
import requests
from bs4 import BeautifulSoup
url_1="https://www.naukri.com/ml-engineer-jobs-in-india?k=ml+engineer&l=india"
url_2="https://www.naukri.com/ml-engineer-jobs-in-india-2"
url_3="https://www.naukri.com/ml-engineer-jobs-in-india-3"
url_4="https://www.naukri.com/ml-engineer-jobs-in-india-4"
url_5="https://www.naukri.com/ml-engineer-jobs-in-india-5"
res1=requests.get(url_1)
print(res1)
# Out:
# <Response [200]>

# %% [markdown]
# However the response object returned by HTTP request of requests library doesn’t have HTML tags,

# %%
soup1=BeautifulSoup(res1.text,'html.parser')
print(soup1)
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# So to get the HTML source of web page we shall use selenium library of Python which is used for automation. I am using Chrome webdriver here.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import time
import pprint

# Specify the full path to the ChromeDriver executable
chrome_service = Service('chromedriver.exe')

# Create Chrome instance with options and service
chrome_browser = webdriver.Chrome(service=chrome_service)
chrome_browser.maximize_window()
#Opens chrome browser and redirects to the link provided in the get method.
chrome_browser.get(url_1)
time.sleep(5)

soup1 = BeautifulSoup(chrome_browser.page_source,'html.parser')
print(soup1.prettify())
# Out:
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://www.googletagmanager.com" rel="dns-prefetch"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/d932e384cdee6676.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/6d152f98b59da981.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/585c79ef85a80701.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/b09725aaa4a54f31.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/17278d85da7314a6.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/5f22ebb3f45ba679.css" rel="stylesheet"/>
# ...

# %%
chrome_browser.get(url_2)
time.sleep(5)

soup2 = BeautifulSoup(chrome_browser.page_source,'html.parser')
print(soup2.prettify())
# Out:
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://www.googletagmanager.com" rel="dns-prefetch"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/d932e384cdee6676.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/6d152f98b59da981.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/585c79ef85a80701.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/b09725aaa4a54f31.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/17278d85da7314a6.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/5f22ebb3f45ba679.css" rel="stylesheet"/>
# ...

# %%
chrome_browser.get(url_3)
time.sleep(5)

soup3 = BeautifulSoup(chrome_browser.page_source,'html.parser')
print(soup3.prettify())
# Out:
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://www.googletagmanager.com" rel="dns-prefetch"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/d932e384cdee6676.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/6d152f98b59da981.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/585c79ef85a80701.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/b09725aaa4a54f31.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/17278d85da7314a6.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/5f22ebb3f45ba679.css" rel="stylesheet"/>
# ...

# %%
chrome_browser.get(url_4)
time.sleep(5)

soup4 = BeautifulSoup(chrome_browser.page_source,'html.parser')
print(soup4.prettify())
# Out:
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://www.googletagmanager.com" rel="dns-prefetch"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/d932e384cdee6676.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/6d152f98b59da981.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/585c79ef85a80701.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/b09725aaa4a54f31.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/17278d85da7314a6.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/5f22ebb3f45ba679.css" rel="stylesheet"/>
# ...

# %%
chrome_browser.get(url_5)
time.sleep(5)

soup5 = BeautifulSoup(chrome_browser.page_source,'html.parser')
print(soup5.prettify())
chrome_browser.close()
# Out:
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://www.googletagmanager.com" rel="dns-prefetch"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/d932e384cdee6676.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/6d152f98b59da981.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/585c79ef85a80701.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/b09725aaa4a54f31.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/17278d85da7314a6.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://static.naukimg.com/s/9/121/_next/static/css/5f22ebb3f45ba679.css" rel="stylesheet"/>
# ...

# %%
job_list_container1=soup1.find_all("div", class_="cust-job-tuple layout-wrapper lay-2 sjw__tuple")
print(len(job_list_container1))
pprint.pprint(job_list_container1)
# Out:
# 20
# ...

# %%
job_list_container2=soup2.find_all("div", class_="cust-job-tuple layout-wrapper lay-2 sjw__tuple")
print(len(job_list_container2))
pprint.pprint(job_list_container2)
# Out:
# 20
# ...

# %%
job_list_container3=soup3.find_all("div", class_="cust-job-tuple layout-wrapper lay-2 sjw__tuple")
print(len(job_list_container3))
pprint.pprint(job_list_container3)
# Out:
# 20
# ...

# %%
job_list_container4=soup4.find_all("div", class_="cust-job-tuple layout-wrapper lay-2 sjw__tuple")
print(len(job_list_container4))
pprint.pprint(job_list_container4)
# Out:
# 20
# ...

# %%
job_list_container5=soup5.find_all("div", class_="cust-job-tuple layout-wrapper lay-2 sjw__tuple")
print(len(job_list_container5))
pprint.pprint(job_list_container5)
# Out:
# 20
# ...

# %%
job_list_container= job_list_container1 + job_list_container2 + job_list_container3 + job_list_container4 + job_list_container5

# %%
# Initialize lists to store job details
job_titles = []
job_locations = []
company = []
key_skills = []

# Initialize an empty list to store individual skills
individual_skills = []

for job in job_list_container:
    try:
        # Extract job title
        title = job.find("a", class_="title").text.strip()
        if title.lower() in ['ml engineer','ml engineer - junior','ml engineer/data scientist', 'ml engineer i', 'ml / data scientist','ml engineer/data scientist','al/ml engineer']:
            job_titles.append('ML Engineer')
        elif title.lower() in ['sr ml engineer','sr. ml engineer', 'senior ml engineer', 'senior ml engineer - Mlops','sr . ml engineer', 'lead ml engineer','ml engineer ii']:
            job_titles.append('Sr. ML Engineer')
        elif title.lower() in ['data scientist','data analyst','data analyst / data scientist','data analyst/data scientist', 'data analyst / scientist 3', 'data scientist -chennai', 'data scientist - ai/ml','software developer - data science','business analyst /data analyst /data scientist','data scientist - ml, python,  - 4-7 years -mumbai/pune/bangalore']:
            job_titles.append('Data Analyst/Data Scientist')  
        elif title.lower() in ['ml Engineer & ml ops', 'ml ops engineer']:
            job_titles.append('ML Ops Engineer')   
        elif title.lower() in ['senior ml ops engineer', 'senior ml ops engineer - wiq']:
            job_titles.append('Sr. ML Ops Engineer')       
        else:
            job_titles.append(title)
    except:
        job_titles.append("None")
    print(title)
    try:
        # Extract job location
        location = job.find("span", class_="locWdth").text.strip()
        if location.lower() in ['bangalore/bengaluru','bengaluru']:
            job_locations.append('Bangalore/Bengaluru')
        elif location.lower() in ['chennai','chennai, tamil nadu']:
            job_locations.append('Chennai')   
        elif location.lower() in ['gurugram, haryana','gurgaon/gurugram']:
            job_locations.append('Gurugram') 
        elif location.lower() in ['hybrid - bangalore/bengaluru','hybrid - bengaluru']:
            job_locations.append('Hybrid - Bangalore/Bengaluru') 
        elif location.lower() in ['mumbai','thane','thane, maharashtra']:
            job_locations.append('Mumbai') 
        elif location.lower() in ['hyderabad, telangana','hyderabad']:
            job_locations.append('Hyderabad')    
        else:
            job_locations.append(location)

    except:
        job_locations.append("None")
    print(location)  
    try:
        # Extract name of the company
        comp_name = job.find("a", class_="comp-name").text.strip()
        company.append(comp_name)
    except:
        company.append("None")
    print(comp_name)
    try:
        # Extract key skills
        skills = job.find('ul', class_='tags-gt').find_all('li', class_='dot-gt tag-li')
        tags_list = [li.text.strip() for li in skills]
        individual_skills.extend(tags_list)
        key_skills.append(",".join(tags_list))
    except:
        key_skills.append("None")
    print(tags_list)

print(len(job_titles))   
print(len(job_locations))   
print(len(company))  
print(len(key_skills))
# Out:
# ML Engineer
# Remote
# Protiviti India
# ['Docker', 'Machine Learning', 'Python', 'Kubernetes', 'SQL', 'Natural Language Processing', 'Spark', 'Ml']
# Ml Engineer - Docker
# Remote
# Protiviti India
# ['Docker', 'Machine Learning', 'Python', 'SQL', 'Natural Language Processing', 'Kubernetes', 'Processing', 'Languages']
# ML Engineer
# Bengaluru
# Aritha Consulting Services
# ['algorithms', 'python', 'data analysis', 'natural language processing', 'neural networks', 'machine learning', 'artificial intelligence', 'sql']
# ML Engineer
# Bengaluru
# Deliverhealth
# ['Computer science', 'ASR', 'Cloud computing', 'Machine learning', 'SCALA', 'Healthcare', 'Data processing', 'Natural language processing']
# Ml Engineer
# Bengaluru(Indira Nagar)
# Healthifyme
# ['Natural Language Processing', 'Computer Vision', 'Deep Learning', 'Pytorch', 'Computer', 'Process', 'Processing', 'Vision']
# ML Engineer
# Bengaluru
# Aritha
# ...

# %%
import pandas as pd
# Create a DataFrame to store the extracted data
job_data = pd.DataFrame({
    "Job Title": job_titles,
    "Location": job_locations,
    "Company": company,
    "Key Skills": key_skills
})

job_data.shape
# Out:
# (100, 4)

# %%
# Print the DataFrame
job_data.head()
# Out:
#               Job Title                 Location                     Company  \
# 0           ML Engineer                   Remote             Protiviti India
# 1  Ml Engineer - Docker                   Remote             Protiviti India
# 2           ML Engineer      Bangalore/Bengaluru  Aritha Consulting Services
# 3           ML Engineer      Bangalore/Bengaluru               Deliverhealth
# 4           ML Engineer  Bengaluru(Indira Nagar)                 Healthifyme
#
#                                           Key Skills
# 0  Docker,Machine Learning,Python,Kubernetes,SQL,...
# 1  Docker,Machine Learning,Python,SQL,Natural Lan...
# 2  algorithms,python,data analysis,natural langua...
# 3  Computer science,ASR,Cloud computing,Machine l...
# 4  Natural Language Processing,Computer Vision,De...

# %%
# Save the DataFrame to a CSV file
job_data.to_csv("naukri_jobs.csv", index=False)

# %% [markdown]
# # Univariate Analysis

# %%
#Data Visualisation 
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(8,5))
job_data['Job Title'].value_counts().plot(kind='bar', color='skyblue')
plt.xlabel('Job Title')
plt.ylabel('Count')
plt.title('Count of Job Titles')
plt.xticks(rotation=90)
plt.show()

# %%
# Create bar chart for Location
plt.figure(figsize=(8, 6))
job_data['Location'].value_counts().plot(kind='bar', color='lightgreen')
plt.xlabel('Location')
plt.ylabel('Count')
plt.title('Count of Locations')
plt.xticks(rotation=90)
plt.show()

# %%
# Create bar chart for Company
plt.figure(figsize=(12, 6))
job_data['Company'].value_counts().plot(kind='bar', color='salmon')
plt.xlabel('Company')
plt.ylabel('Count')
plt.title('Count of Companies')
plt.xticks(rotation=90)
plt.show()

# %%
skills={}
for skill in individual_skills:
    
    if skill.lower() in ['ml','machine learning', 'machine' ,'ml engineer', 'ml frameworks','ml algorithms','ml flow','mlflow','machine learning algorithms','deep learning']:
        skill='Machine Learning'
    elif skill.lower() in ['tensorflow']:
        skill='Tensorflow'
    elif skill.lower() in ['big data','data','data analytics','data analysis','analysis', 'data modeling', 'data modelling','teradata', 'data processing', 'analytics','analytical','modeling','training','data mining','mining','model building','regression','linear regression','logistic regression','data classificaton']:
        skill='Data Analytics And Modelling' 
    elif skill.lower() in ['process', 'processing', 'data processing', 'data wrangling','data collection']:
        skill='Data Wrangling'     
    elif skill.lower() in ['nlp', 'natural language processing']:
        skill='Natural Language Processing' 
    elif skill.lower() in ['ai', 'artificial intelligence','al','ai/ml','ai ml','aiml']:
        skill='Artificial Intelligence'  
    elif skill.lower() in ['python']:
        skill='Python' 
    elif skill.lower() in ['pytorch']:
        skill='Pytorch' 
    elif skill.lower() in ['api design and development','api']:
        skill='Api Design And Development'     
    elif skill.lower() in ['computer vision']:
        skill='Computer Vision'   
    elif skill.lower() in ['ci/cd','cicd','continuous integration']:
        skill='CI/CD' 
    elif skill.lower() in ['azure','cloud','azure ml studio','azure cloud','azure ai cloud','azure administration','aws cloud','aws cloud platform','aws bedrock','microsoft azure','manager technology','technology','aws','cloud computing']:
        skill='Cloud Technology And Computation'  
    elif skill.lower() in ['development','model development','skill development']:
        skill='Model Development'
    elif skill.lower() in ['management','product management']:
        skill='Product Management'    
    elif skill.lower() in ['ops','devops','mlops','mlops tools','ml ops']:
        skill='Machine Learning + DevOps'
    elif skill.lower() in ['video','audio','editing','video editing','audio & video editing']:
        skill='Editing(Audio, Video or Both)'
    elif skill.lower() in ['sql','mysql','oracle','database programming','nosql']:
        skill='Database Management'
    elif skill.lower() in ['data bricks','bricks','azure databricks']:
        skill='Data Bricks'    
    elif skill.lower() in ['data science','data scientist','computer science']:
        skill='Data Science'
    elif skill.lower() in ['data structures','coding']:
        skill='Coding/Data structures'    
    skills[skill]=skills.get(skill,0)+1

print(skills)
# Out:
# {'Docker': 3, 'Machine Learning': 121, 'Python': 31, 'Kubernetes': 3, 'Database Management': 10, 'Natural Language Processing': 26, 'Spark': 4, 'Data Wrangling': 10, 'Languages': 2, 'algorithms': 2, 'Data Analytics And Modelling': 46, 'neural networks': 2, 'Artificial Intelligence': 16, 'Data Science': 45, 'ASR': 2, 'Cloud Technology And Computation': 25, 'SCALA': 1, 'Healthcare': 7, 'Computer Vision': 8, 'Pytorch': 10, 'Computer': 1, 'Vision': 2, 'Packaging': 1, 'Programming': 2, 'Neural Networks': 1, 'Scikit-learn': 1, 'Model Development': 6, 'Mahine learning': 1, 'Open soure': 1, 'Seletion proess': 1, 'Debugging': 6, 'Reruitment': 1, 'Artifiial Intelligene': 1, 'Gag': 1, 'Programg': 1, 'Engineer': 1, 'Algorithms': 1, 'Science': 5, 'Redhat': 1, 'orchestration': 5, 'Deployment': 7, 'Product Management': 4, 'PIL': 1, 'NLG': 1, 'LLM': 7, 'PPA': 1, 'NISA': 1, 'Nltk': 1, 'Huggingface': 1, 'Generative AI': 2, 'Spacey': 1, 'Spacy': 1, 'GCP': 8, 'Troubleshooting': 1, 'Operations': 4, 'Obje
# ...

# %%
df_dict =pd.DataFrame(skills.items(), columns=['Skill', 'Frequency'])
# Sort DataFrame by the "Frequency" column in descending order
Skills_sorted = df_dict.sort_values(by='Frequency', ascending=False)
Skills_sorted
# Out:
#                             Skill  Frequency
# 1                Machine Learning        121
# 10   Data Analytics And Modelling         46
# 13                   Data Science         45
# 2                          Python         31
# 5     Natural Language Processing         26
# ..                            ...        ...
# 45                            PPA          1
# 43                            NLG          1
# 42                            PIL          1
# 38                         Redhat          1
# 244                         Excel          1
#
# [245 rows x 2 columns]

# %%
Skills_sorted=Skills_sorted.head(10).copy()
Skills_sorted
# Out:
#                                Skill  Frequency
# 1                   Machine Learning        121
# 10      Data Analytics And Modelling         46
# 13                      Data Science         45
# 2                             Python         31
# 5        Natural Language Processing         26
# 15  Cloud Technology And Computation         25
# 12           Artificial Intelligence         16
# 58            Coding/Data structures         14
# 60         Machine Learning + DevOps         10
# 19                           Pytorch         10

# %%
import seaborn as sns
#Pie chart of top 10 skills
# Plotting the pie chart using seaborn
plt.figure(figsize=(8, 8))
sns.set_palette('bright')
plt.title('Pie chart for top 10 key skill set')
plt.pie(Skills_sorted['Frequency'], labels=Skills_sorted['Skill'], autopct='%1.1f%%',startangle=90)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
from wordcloud import WordCloud

# %%
unique_skills=list(set(individual_skills))
text_data=",".join(Skills_sorted['Skill'][:50])
# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_data)

# Display word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='spline16')
plt.axis('off')
plt.title('Skills Word Cloud')
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
# Create a pivot table to aggregate the count of job titles by location
pivot_table = job_data.pivot_table(index='Company', columns='Job Title', aggfunc='size', fill_value=0)

# Plot a stacked bar chart
plt.figure(figsize=(12, 8))
pivot_table.plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of Job Titles by Location')
plt.xlabel('Location')
plt.ylabel('Count')
plt.legend(title='Job Title', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20696\2966200192.py:12: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
